# %% [markdown]
# # h1: Data Science Tools And Ecosystem

# %% [markdown]
# ![2-title.png](attachment:73b788fc-8fca-4930-b8e7-c09c85706fb1.png)

# %% [markdown]
# ### In this notebook, Data Science Tools and Ecoystem are summarized.
# ##### Data science tools encompass a range of software and libraries used for collecting, analyzing, and visualizing data. Popular tools include Python libraries like Pandas, NumPy, and scikit-learn, along with R programming language. Visualization tools like Matplotlib and Tableau aid in presenting insights. Frameworks like TensorFlow and PyTorch are vital for deep learning tasks.

# %% [markdown]
# ![3-intro.png](attachment:a6d0a03b-e6ad-4492-a338-4257e1cf7799.png)

# %% [markdown]
# **Objectives**
# - Popular languages for data science
# - Popular libraries for data science
# - Data science tools
# - Arithmetic evaluatin in python

# %% [markdown]
# ![10-objectives.png](attachment:e443bc13-603f-42be-968c-e6b9bf380be9.png)

# %% [markdown]
# ### Some of the popular data science languages that data scientists use are:
# 1. Python
# 2. R
# 3. Scala
# 4. Julia

# %% [markdown]
# ![4-dslanguages.png](attachment:fdb2f60f-24bd-4d30-85fe-81ae07daf888.png)

# %% [markdown]
# ### Some of the commonly used libraries used by data scientists include:
# 1. Pandas
# 2. Numpy
# 3. Matplotlib
# 4. Tensorflow
# 5. Keras
# 6. Pytorch

# %% [markdown]
# ![5-dslibraries.png](attachment:9c8a47cf-a6f8-4414-ac14-8e563ef06eaf.png)

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | Python |
# | R |
# | Apache Spark |
# | Apache Hadoop |

# %% [markdown]
# ![6-dstools.png](attachment:759e2426-0d13-49a1-b14e-e4dddd510d01.png)

# %%
#### Below are some example of evaluating arithmetic expressions in python
10+5

# %%
10-7

# %%
3*5

# %%
15/5

# %% [markdown]
# ![7-introarithmetic.png](attachment:11009bb5-2d22-4c05-bae2-b0103ddf8bf3.png)

# %%
### This is a simple arithmetic expression to multiply then add integers
(3*4)+5

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:45c7c3f8-1305-4679-80c3-81bbfab24797.png)

# %%
# This will convert 200 minutes to hours by dividing by 60
200/60

# %% [markdown]
# ![9-minutestohour.png](attachment:61584e5a-377d-4452-bc56-13811443d2d9.png)

# %% [markdown]
# ## Author
# ### Allaudin Ansari
